# %%
# Facebook data mining bootcamp !!!
# HCS Bootcamp 1 by Yooni Park and John Hwang

# important imports 
import os
import json
import numpy as np
import pylab as pl
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime
from heapq import nlargest

# %%
# globals 

CURRENT_DIRECTORY = os.getcwd()
NUMBER_TO_ANALYZE = 700
MESSAGE_THRESHOLD = 0

# %%
# get json data for the individual chats in your messages folder 

def get_json_data(chat):
    try:
        # you may need to change the directory path, depends on where you've downloaded your fb messages to. 
        json_location = CURRENT_DIRECTORY + "/messages/inbox/" + chat + "/message_1.json"
        with open(json_location) as json_file:
            json_data = json.load(json_file)
            return json_data
    except IOError:
        pass # some things the directory aren't messages (DS_Store, stickers_used, etc.)


    
# create new globals for data to be plotted 
chats = os.listdir(CURRENT_DIRECTORY + "/messages/inbox")[:NUMBER_TO_ANALYZE]
sorted_chats = []
final_data_messages = {}
final_data_times = {}
final_data_words = {}
invalid_message_count = 0



print('Analyzing ' + str(min(NUMBER_TO_ANALYZE, len(chats))) + ' chats...')
# Out:
# Analyzing 389 chats...

# %%
# sort data into new gobals 

for chat in chats:
    url = chat
    json_data = get_json_data(chat)

    if json_data != None:
        messages = json_data["messages"]
        if len(messages) >= MESSAGE_THRESHOLD:
            sorted_chats.append((len(messages), chat, messages))

sorted_chats.sort(reverse=True)

print('Finished processing chats...')
# Out:
# Finished processing chats...

# %%
# continue sorting messages into the new globals (dictionaries)
# you may have to alter this code a bit depending on what functions you would like to add

tireds = {}
swearers = {}
commonexchanges = {}
invalidmessages = {}

for i, (messages, chat, messages) in enumerate(sorted_chats):
    number_messages = {}
    person_to_times = {}
    number_words = {}

    print(str(i+1) + " - " + str(len(messages)) + " messages - " + str(chat))

    for message in messages:
        try:
            name = message["sender_name"]
            time = message["timestamp_ms"]
            message_content = message["content"]

            number_messages[name] = number_messages.get(name, 0)
            number_messages[name] += 1

            person_to_times[name] = person_to_times.get(name, [])
            person_to_times[name].append(datetime.utcfromtimestamp(time/1000.0))

            number_words[name] = number_words.get(name, [])
            number_words[name].append(len(message_content.split()))
            
            if 'im tired' in message_content:
                if name in tireds:
                    tireds[name] += 1
                else:
                    tireds[name] = 1
                    
            if 'shit' or 'fuck' or 'damn ' or 'gaeshekki' or 'shippar' or 'hell' or 'shekki' or 'motherfucker' in message_content:
                if name in swearers:
                    swearers[name] += 1
                else:
                    swearers[name] = 1
                    
            if message_content in commonexchanges:
                commonexchanges[message_content] += 1
            else:
                commonexchanges[message_content] = 1
                
        except KeyError:
            # happens for special cases like users who deactivated, unfriended, blocked
            invalid_message_count += 1

    final_data_messages[i] = number_messages
    final_data_times[i] = person_to_times
    final_data_words[i] = number_words

    

print('Found ' + str(invalid_message_count) + ' invalid messages...')
print('Found ' + str(len(sorted_chats)) + ' chats with ' + str(MESSAGE_THRESHOLD) + ' messages or more')
# Out:
# 1 - 10000 messages - orchdorchs_ej5qcv9ffq
# 2 - 10000 messages - monkas_deia__yuig
# 3 - 10000 messages - michaelyang_ocpr8ognrg
# 4 - 10000 messages - lucasyuan_muqof-dqow
# 5 - 10000 messages - loveDecagon_3yAsGKK8eQ
# 6 - 10000 messages - kevinlu_c4cqxlzuvq
# 7 - 10000 messages - jeonghoonjasonchoi_bscy1kxyua
# 8 - 10000 messages - jenlo_14yahkhbnw
# 9 - 10000 messages - imanantisocialkid_NYuyzed9ng
# 10 - 10000 messages - hyunwoodo_iuu3pyocog
# 11 - 10000 messages - bysohoes_t5rkjvwmjg
# 12 - 10000 messages - awakeover_exxkwic1ra
# 13 - 10000 messages - asianpalnons_izvy9dno_g
# 14 - 10000 messages - ashleychen_8r9ptjtz7g
# 15 - 10000 messages - anabundanceofcatherines_7a6rggg_vq
# 16 - 10000 messages - VivianLi_27KdRZXq0Q
# 17 - 10000 messages - PatrickNie_84wba6l7JQ
# 18 - 9604 messages - asianpalswithautotranslate_heoroemgiw
# 19 - 9457 messages - junulee_bmvbcuy51w
# 20 - 8245 messages - toes_aszqrcjmla
# 21 - 6112 messages - mitchellparus_hhtttvyyda
# 22 - 5196 messages - habeodeu18hagbeon_nyvez7shiw
# 23 - 4620 messages - williamyang_xsgwhypdqa
# 24 - 4157 messages - deeptalks_dkwjdzvgrw
# 25 - 4079 messages - frootsalahd_32s7unokza
# 26 - 4034 messages - bowenchen_k4stduoy5w
# 27 - 3995 messages - mads_tzwswsgulq
# 28 - 3805 messages - alcoholicsandhanna_bp-ptfcb-g
# 29 - 3528 messages - pakwansing_vzshco3lsg
# 30 - 3226 messages - aaronhai_e52b2qunoa
# 31 - 2684 messages - cynthiachen_wxjagkqahw
# 32 - 2504 messages - 75ofeastasiasgdp18ofworldgdp_sf2c-i9f9w
# 33 - 2316 messages - heatheryun_ithk3tscjg
# 34 - 2273 messages - pb20172018_bfana3vy4g
# 35 - 2264 messages - bubbles_whr2qrzgtq
# 36 - 2187 messages - kevinye_pkxmcuacra
# 37 - 2105 messages - paritybits20162017__8h14ef77a
# 38 - 2033 messages - jasonchin__-epvavuoa
# 39 - 2019 messages - michaeltu_5zmkka8j1a
# 40 - 1999 messages - thealternateuniverse_lsfwctocaw
# 41 - 1832 messages - michaelandericfanfiction_4snag3sbjg
# 42 - 1743 messages - javafilespls_ekrzgv7qwa
# 43 - 1682 messages - kyleyuan_n1mkpinpxw
# 44 - 1678 messages - cs50squad_6-h2j46r8w
# 45 - 1626 messages - matthewho_vvmtlki7zg
# 46 - 1590 messages - thisisnotafashionshow_s2riciqptq
# 47 - 1462 messages - springbreak_bigmq2sukq
# 48 - 1445 messages - jenlo_gq0zlawdpg
# 49 - 1337 messages - harvard2022bostonians_yufdyubfnq
# 50 - 1331 messages - cs_2pucsh5vqq
# 51 - 1239 messages - sandramoon_ybbyhwuvla
# 52 - 1226 messages - geonbae_mtbj6dxdgg
# 53 - 1192 messages - johnhwang_t3xflaw4aa
# 54 - 1129 messages - thursdayat3ish_ls1mxegcbq
# 55 - 1081 messages - chriskwon_y7yi4_1xig
# 56 - 1044 messages - 10dewolfe6th_hg0mtqxnza
# 57 - 1031 messages - girlsonly_yug7tpucza
# 58 - 951 messages - chipsguacsalsa_nwaqrgivgg
# 59 - 837 messages - endgamesuepullsthru_oghfbh1csq
# 60 - 807 messages - harvardmathmonkeysteam_vefx9hgzfg
# 61 - 758 messages - matchatea_htpr_xttha
# 62 - 740 messages - chem_lnz7etznvw
# 63 - 735 messages - alishayi_77cicj9hpa
# 64 - 724 messages - berryblast_gkxmi4s1bg
# 65 - 686 messages - alc_5mf_bov3cq
# 66 - 677 messages - jensbloominglovelife_tsekzvc8eq
# 67 - 666 messages - letsgetemwet_nkmtjgq2og
# 68 - 660 messages - oliviawhite_f8smm6ypvg
# 69 - 656 messages - khushisoni_fho_abxn8w
# 70 - 648 messages - ericlin_ytw53ulr5w
# 71 - 646 messages - oversharingisnotnice_lzasv_j2fa
# 72 - 634 messages - junushoes_ngh43aoszq
# 73 - 618 messages - ihateplanningeveryonesanalcoholicexceptmit_yxxuopemsw
# 74 - 569 messages - whatacuteinteraction_lz6d9cqllw
# 75 - 534 messages - kisafresh_8ribaazbhw
# 76 - 528 messages - avalon_fqgfkqsoiq
# 77 - 524 messages - ramonapark_wf61vxi0rq
# 78 - 507 messages - bysviolins60thseason_t9uqlxrn6q
# 79 - 488 messages - dowaiverorbesacrificed_pd9chmlonq
# 80 - 475 messages - yoonispartywillhavelowattendance_nqqxj84yrw
# 81 - 458 messages - hangoutattempt_ikv6gadfow
# 82 - 444 messages - pacho_yrc5rqjnwa
# 83 - 422 messages - broadwayfieldtripandharvardconductorsclub_gv0fxfh5og
# 84 - 414 messages - madrigals_85r-qg75la
# 85 - 408 messages - freehousingwhee_jb6unma-3q
# 86 - 404 messages - clivechan_h6a3ajce1a
# 87 - 400 messages - birthdayhotpot_xkujsh_4dg
# 88 - 380 messages - hannatuomi_zlrmvwzdvq
# 89 - 379 messages - bowenchenandvivianli_vqehh05jlg
# 90 - 374 messages - harvardfoodgang_-qxxqzysrq
# 91 - 353 messages - birthday_6tzlrnoskq
# 92 - 349 messages - claireyu_f_cmo6swkg
# 93 - 343 messages - minigalf_l-vsbk5axw
# 94 - 335 messages - idekwhatthisisbutwhatever_tcl3ka42ea
# 95 - 332 messages - meetatjens835_a1np74kcea
# 96 - 327 messages - wtfisthis_mtzq4op1ug
# 97 - 327 messages - evanweissburg_g4ekblccfg
# 98 - 317 messages - billgao_ccurjj9wjw
# 99 - 315 messages - bysquadclaire_8npl6igyeq
# 100 - 304 messages - bysviolins1617_pndgvntqeq
# 101 - 300 messages - thirstyasf_fgueccqzkg
# 102 - 288 messages - ryanleung_tenythn4dg
# 103 - 288 messages - jackdefay_zhcb72vxxq
# 104 - 287 messages - heathershousepool_qtns_yxcoq
# 105 - 285 messages - madripowerfulwomen_fuwu0s5ovw
# 106 - 279 messages - albertzhang_hlicmjp6qa
# 107 - 273 messages - rebeccaye_lhvetr4jdq
# 108 - 273 messages - angelu_kvnat9u1ka
# 109 - 232 messages - yoonisthanksgivingminusyooni_3-mzkex_8q
# 110 - 224 messages - carolynge_czw48ui8gq
# 111 - 223 messages - nextonewhochangeschatnameisadegen_e26tn3wpba
# 112 - 205 messages - nicholasmanickashill_qbdg3v4plw
# 113 - 205 messages - dannyroh_fn8mhjltlw
# 114 - 195 messages - anighttoremember_e92nmbc2mg
# 115 - 187 messages - hackathonsquad_gkwks_-aca
# 116 - 179 messages - kevinzhou_mjxzfl8kug
# 117 - 175 messages - taeyeonkim_otxascrxpq
# 118 - 165 messages - albertshin_gmvfhk_82q
# 119 - 161 messages - beccapartay39robinsonroad2tosometimeafter_gm9eagcnpq
# 120 - 159 messages - matthewhocarolyngeoliviaxuandjunulee_uznfylxgja
# 121 - 157 messages - lightsoffconfessionsession_1v0ryu2aoa
# 122 - 154 messages - peoplewhoareactuallyaroundanddowntohang_p4mjo3wnsa
# 123 - 149 messages - soolee_8i_kqh83dw
# 124 - 149 messages - raissali_v6iexs_ova
# 125 - 149 messages - cirullissquad_v2covnieiq
# 126 - 143 messages - supersexysaturdaymornings_2qhuitq0gq
# 127 - 142 messages - ccstruggles_xq28kes_za
# 128 - 137 messages - austinkwoun_unrgdwqa4a
# 129 - 136 messages - claireyuandtaeyeonkim_qeioiybsxg
# 130 - 133 messages - lhsasianstudentunion201718_kfd_o1lcbg
# 131 - 129 messages - adinazhang_ptou0nuw7q
# 132 - 128 messages - 3amddlcreaccsonly_nhm35ibm1w
# 133 - 116 messages - suepurohit_9m3mggjakq
# 134 - 114 messages - rebeccayeandvivianli_gd1eorkrvg
# 135 - 113 messages - jayyi_wqhncdbxtw
# 136 - 111 messages - nikkikim_8ohvg7nvra
# 137 - 110 messages - suesbirth_kxewuaad8q
# 138 - 110 messages - bobarun_gveetvj1hw
# 139 - 107 messages - jeffreychang_ontkvmhahq
# 140 - 107 messages - cynthiafu_sz6kobmh9a
# 141 - 106 messages - viviansthreateningchat_qmp7dzk_7w
# 142 - 106 messages - lobstersaregood_akzpav6n2w
# 143 - 105 messages - bccultureshow_dhqrt_euig
# 144 - 104 messages - saraqu_5jrv1bienw
# 145 - 104 messages - physicsmousetraptrike_byf7fbdwca
# 146 - 104 messages - kevinrho_fd9x4sy98q
# 147 - 102 messages - armys_ihdzge3bhg
# 148 - 101 messages - juliakan_6ds2xg8g7a
# 149 - 100 messages - michaellim_wdpp2jmxsq
# 150 - 96 messages - matthewhoandbowenchen_v0c-anql_g
# 151 - 96 messages - chanseolee_w2jaoubsww
# 152 - 92 messages - scrimmagedrivers_sjpcxzdybq
# 153 - 91 messages - nadineleefacebookuseralbertshinand6others_ayhfek2f1w
# 154 - 88 messages - richardchang_x9yfgzthog
# 155 - 87 messages - joannewang_ruzhp5mqla
# 156 - 86 messages - cakewalk_t953_s2afg
# 157 - 86 messages - anushkarathi_ttvi7ejufq
# 158 - 83 messages - jenlorebeccayevivianliandhannatuomi_7zkjg89ljg
# 159 - 80 messages - davidchen_xlnigzoasg
# 160 - 79 messages - matthewhocarolyngeandrewluandericlin_haeszpdrvg
# 161 - 79 messages - bowenchenandericlin_0lx8rlercg
# 162 - 76 messages - chinatownpals_y2321hteya
# 163 - 73 messages - robotzoo_6uzbvbwgeq
# 164 - 73 messages - mathonebee_zx5rjrwcra
# 165 - 72 messages - heatheryunmichaelyangjayyiand5others_fxzuot8iqw
# 166 - 72 messages - aradhnajohnson_1wnfi2oa_a
# 167 - 71 messages - rebeccabday3_epy-kwnhsq
# 168 - 71 messages - movie_gvqqprppuq
# 169 - 71 messages - helpmeout_q5jx9j3kgw
# 170 - 69 messages - thebigd_awe-folpjg
# 171 - 69 messages - pikapika_wjep9kcfkq
# 172 - 68 messages - vivianliandcynthiafu_oryaomelkg
# 173 - 68 messages - claireyuandannapark_jiurlolr2q
# 174 - 66 messages - seoulmiting_t_iaet4a8g
# 175 - 66 messages - pbprogramming1617_veopmm5xhq
# 176 - 66 messages - defacsgc_v9-4verpfg
# 177 - 65 messages - donng_h4ib5pu0ja
# 178 - 65 messages - dancingonthegraveofsouthcarolitna_myuvpl1zpw
# 179 - 63 messages - alisonzeng_6qto5jx_jg
# 180 - 60 messages - matthewhocarolyngeandcatherineyeo_2u6micwplg
# 181 - 58 messages - jeanachoi__qfyj32yyq
# 182 - 58 messages - gymday_eklxi1x5hg
# 183 - 57 messages - dinner_o8ntgunfkw
# 184 - 54 messages - sarahyang_bhrhoebqaa
# 185 - 54 messages - sadflameybois__7me4h3urw
# 186 - 54 messages - jasonkottas_ubmwnr_o_w
# 187 - 54 messages - andrewzhang_cfwxsifwag
# 188 - 53 messages - chcorsomething_eizeuip3gq
# 189 - 53 messages - andyspiersanddanielsong_5qhg2fwiea
# 190 - 52 messages - angelawu_jc5fshktag
# 191 - 50 messages - cheese_ap28o35drq
# 192 - 48 messages - beverlyliu_-faudgi4ag
# 193 - 45 messages - nanbeijiayuanparty_6rhvvmbxza
# 194 - 44 messages - matthewhoandoliviaxu_b4ydkx14pg
# 195 - 43 messages - annaparkmaggiemengandsunjungyum_huhufdivwq
# 196 - 42 messages - monatavangar_cix6cex19a
# 197 - 42 messages - ksacsa_c_6v7rhw1q
# 198 - 42 messages - karaxie_8vudrkbrhq
# 199 - 42 messages - faithng_p4_hv6t3xq
# 200 - 42 messages - experientialew_3p5lhbviqa
# 201 - 41 messages - briankim_yrmjn4obuq
# 202 - 40 messages - ericnam_nkkrlaxlog
# 203 - 39 messages - jinyungsuh_cvnwqsz80q
# 204 - 39 messages - jenniferkyoungwon_0qmduwpupg
# 205 - 39 messages - dumplinghousewithmyparents_qxuzkxsdbw
# 206 - 39 messages - andrewyun_xr3lrite8g
# 207 - 37 messages - ricklee_zp27bbhaka
# 208 - 37 messages - raytheonboysandgirlsclub_nbu8vagphq
# 209 - 37 messages - heatheryunmichaelyangvivianliand3others_vojmsxletq
# 210 - 36 messages - classcouncil_tlocu3r94w
# 211 - 36 messages - annawang_67ftcs_-xg
# 212 - 35 messages - dresssquad_9jd63yxljw
# 213 - 34 messages - matthewhocarolyngeoliviaxuand2others_nib9gwt5ow
# 214 - 33 messages - matthewhocarolyngebowenchenand5others_qcsa02bllq
# 215 - 33 messages - graceabe_m9judhap2w
# 216 - 31 messages - matthewhocarolyngeericlinand2others_syxtumfvpg
# 217 - 31 messages - matthewhoandericlin_bwtytpxqxg
# 218 - 31 messages - martinng_p6a94uq5og
# 219 - 31 messages - jenloandhannatuomi_dwrmnpkrba
# 220 - 30 messages - suepurohitandanushkarathi_9cg8tkmmga
# 221 - 29 messages - juliachiang_vdtyg5cr6a
# 222 - 28 messages - minalee_jjbzdsc1lq
# 223 - 28 messages - matthewhobowenchenericlinand3others_qo2nkcuakw
# 224 - 28 messages - ericchen_zb4s5s2rjw
# 225 - 28 messages - ceciliabaekandalishayi_p4gsyc177q
# 226 - 28 messages - aslightlyoddshoppingsubset_eoioov_0jq
# 227 - 27 messages - morganzvezdov_pn2nbtdq3a
# 228 - 27 messages - henryhoffmanbillgaoandyspiersand43others_jynj4ggtgq
# 229 - 27 messages - billgaopeterrowleybriancoburnand3others_bmdua7xgug
# 230 - 26 messages - zacharyhahndupont_zig7rzwjvg
# 231 - 26 messages - thanksgivingdinner_hw40wvf50w
# 232 - 26 messages - sanjanapuri_9hxebp83rg
# 233 - 26 messages - ceciliabaek_je4-g2fbhw
# 234 - 25 messages - hafsahassan_51_elxg0aw
# 235 - 25 messages - annapark_twdxcrejzq
# 236 - 24 messages - mockingjaysundayafter430_diubty-7aa
# 237 - 24 messages - martinngphurbasherpaanddonng_5b6p7gulha
# 238 - 24 messages - jeanekhang_uamcfoaria
# 239 - 24 messages - harvardppl_99q-nfbuqw
# 240 - 23 messages - wendywu_uazboliwvw
# 241 - 23 messages - oliviakormos_un9dqbzsoa
# 242 - 23 messages - natalieramesh_d-7ssfr9bq
# 243 - 23 messages - frankma_pqowxcj7wa
# 244 - 22 messages - oliviaxu_8xxzi5993w
# 245 - 22 messages - heatheryunandhyunwoodo_d6yvhmszdg
# 246 - 21 messages - timothyli_fvk2g-qztq
# 247 - 21 messages - pbsoftware_0jn5-qlyig
# 248 - 21 messages - arytonhoi_sddnzdwujq
# 249 - 21 messages - antoniamartinnucatola_8nrcwim0pq
# 250 - 20 messages - uwu_bs6nyjkjlw
# 251 - 20 messages - jeonghoonthedealer_oxsa5a2ixq
# 252 - 20 messages - albertshincarolyngealishayiandjunulee_dmahnkikzw
# 253 - 19 messages - yvettehan_gtlc2_dmmg
# 254 - 19 messages - yasmineelkattanvivianliirinacostacheand2others_1kvfvk_d4w
# 255 - 19 messages - jenloheatheryunjuliachiangandvivianli_iqaglq1kla
# 256 - 18 messages - maggiezhang_so-2fs9ena
# 257 - 18 messages - kristinxie_ua-i2vg28q
# 258 - 18 messages - joshuachiang_udquhzzogw
# 259 - 17 messages - thefriendlyblockinggroup_kxxdj7janw
# 260 - 17 messages - rebeccayehannatuomiandashleychen_gxua0reyxw
# 261 - 17 messages - noahlee_chgiqcqdaa
# 262 - 17 messages - lilyge_py5pkwflhg
# 263 - 17 messages - juliachun_3zsyjcpb2q
# 264 - 17 messages - johnhwang_fi_d6mqd6g
# 265 - 17 messages - brunchclub_y_k5-jvqqw
# 266 - 16 messages - shopping_hjh8o3xy8w
# 267 - 16 messages - mishafischer_9g7csqyouq
# 268 - 16 messages - fedsminionsexminions_ejsipvsdug
# 269 - 16 messages - elizabethding_ixz6dobdjw
# 270 - 16 messages - chrislee_casm5wyqaw
# 271 - 16 messages - bysveritassquad_kpgt8iqcmw
# 272 - 16 messages - amandadai_rh0vh4hwhg
# 273 - 16 messages - alishayiandsandramoon_redqqdf9ew
# 274 - 15 messages - zehanzhou_ihn1r0v4ag
# 275 - 15 messages - suyeonlee_tpl2aicbzq
# 276 - 15 messages - nikkireznichenko_jipw9hbnqw
# 277 - 15 messages - michelli_3mvgo2nzna
# 278 - 15 messages - jennagelinas_kn8uqcferg
# 279 - 15 messages - emilyzhang_qqlwvfslrw
# 280 - 14 messages - vincentsong_5otxdvtqca
# 281 - 14 messages - jinakim_szf_pkapja
# 282 - 14 messages - jenlorebeccayeandvivianli_3lwh4yotua
# 283 - 14 messages - idkwhattonameourgroup_svlkwzy3kw
# 284 - 14 messages - andrewli_dmenf5cmlq
# 285 - 13 messages - sophiacheng_qgfg8p11dq
# 286 - 13 messages - rachelchau_i-n8ejbazw
# 287 - 13 messages - pietersvenson_z0onxwqrig
# 288 - 13 messages - joellee_tcwg2kj3ta
# 289 - 13 messages - electionscommittee_rruhliezow
# 290 - 13 messages - altos201718_mtdmncpmtq
# 291 - 12 messages - milocalvoplateromartinngphurbasherpaanddonng_h3sxu2q0ta
# 292 - 12 messages - michelletang_kc6h8k-e2w
# 293 - 12 messages - katenie_b5hygtub9a
# 294 - 12 messages - hayatoshiotsubowenchenanthonyzhuandkevinhuang_q2f0sgy8ia
# 295 - 12 messages - hannatuomiandmichaeltu_lyshhadoig
# 296 - 12 messages - daniellekerr_tl2ek4oupw
# 297 - 12 messages - carolinechung_nxsp6s4blg
# 298 - 12 messages - annepackard__wbj-dmr-g
# 299 - 11 messages - kathryntian_ditqfxrghg
# 300 - 11 messages - karischoi_ituxxcm2aq
# 301 - 11 messages - janabelxia_yarja4cmdg
# 302 - 11 messages - freshmenpubwecode_geaymnvkwq
# 303 - 11 messages - billgaopeterrowleybriancoburnand9others_o1bksll6eg
# 304 - 11 messages - anikamehra_oumlcxdrfq
# 305 - 11 messages - albertshinandjunulee_0bgluvjj0w
# 306 - 10 messages - sierratseng_cfutppufsg
# 307 - 10 messages - matthewhoericlinandjunulee_2fth4t4waq
# 308 - 10 messages - liamnovelline_b7aznaozia
# 309 - 10 messages - janejung_q3aowblpca
# 310 - 10 messages - carolinesears_y_4gg5qatg
# 311 - 10 messages - bowenchenericlinandsandramoon_ggumi3a4ew
# 312 - 9 messages - stephanieyao_wpet-u6sva
# 313 - 9 messages - maggiemeng_unv1bmz-qw
# 314 - 9 messages - kaitrepka_rjxpl85auq
# 315 - 9 messages - jingyixu_xpwwpmtwjg
# 316 - 9 messages - emilymoon_xuypm0mctq
# 317 - 9 messages - datamatch_14s2jyaw1w
# 318 - 9 messages - cassidyteng_-uxbszkd4q
# 319 - 8 messages - saffronhuang_1pwcfo6olq
# 320 - 8 messages - nadinelee_roorlzzi0g
# 321 - 8 messages - misasadin_2eezyq5jcq
# 322 - 8 messages - matthewhooliviaxuandericlin_lkcsvo65ja
# 323 - 8 messages - lavanyasingh_cw9jl7o33g
# 324 - 8 messages - danielseong_htirnteqya
# 325 - 8 messages - bestsrsroom_tmsvbrsmhq
# 326 - 7 messages - phurbasherpa_pl6zqlpepa
# 327 - 7 messages - minwoocho_axuxhlezzq
# 328 - 7 messages - khushisonigraceabesuepurohitandanushkarathi_jc7ldmpniw
# 329 - 7 messages - kateluo_g6afll60ja
# 330 - 7 messages - jasoniannuzzi_nnitswt29q
# 331 - 7 messages - hyunwooshin_4b8rgrzp5a
# 332 - 7 messages - ericlinandjunulee_khftkrm5zw
# 333 - 7 messages - blessed_serv6gv3dq
# 334 - 6 messages - yoojeekim_8ibtewlwpq
# 335 - 6 messages - oliviaxuandlynnexie_oea_3pknfa
# 336 - 6 messages - karenlynnyang_ukmhpv7jga
# 337 - 6 messages - jasonfan_41jlipjdxq
# 338 - 6 messages - jackmitchell_iyivz6cgow
# 339 - 6 messages - ejinjeong_ukz4sntd4q
# 340 - 6 messages - davidma_rs1gcp2w-a
# 341 - 6 messages - bowenchenalishayiandsandramoon_abwnwevkvw
# 342 - 5 messages - vivekgopalakrishnan_bly2-qmx-a
# 343 - 5 messages - vinnyhouh_bk1cqvrrka
# 344 - 5 messages - sunjungyum_w9j0eur13q
# 345 - 5 messages - singingbeachesgardenhoe_uofk7zg3sg
# 346 - 5 messages - sampak_62zypkiqsa
# 347 - 5 messages - rileymyers_78satyphug
# 348 - 5 messages - nilaannadurai_zxwsifsaoa
# 349 - 5 messages - laurelsoulier_nqeli-pugq
# 350 - 5 messages - cliffordchen__dkzj_ygxw
# 351 - 5 messages - anniemiall_ccrzp8dbmw
# 352 - 5 messages - amywang_iatkqvtu-a
# 353 - 4 messages - yonglidich_ad3enkdykw
# 354 - 4 messages - tamarakamis_tfkexjkp6q
# 355 - 4 messages - oversight_71_wfevh2w
# 356 - 4 messages - malikaumar_frxbd4jyia
# 357 - 4 messages - kristinchiu_c71nqpebza
# 358 - 4 messages - julianlee_k1mv47wpmw
# 359 - 4 messages - hayeunkim_xinfaolfkq
# 360 - 4 messages - emillyfan_7l88unpwzw
# 361 - 4 messages - bryankim_wdrf8isc3g
# 362 - 4 messages - allisonlee_yelajfr7aa
# 363 - 3 messages - woojinlim_vz8b8rdznw
# 364 - 3 messages - wcalums_qincunvftg
# 365 - 3 messages - seoyoonkim_1saprspiiw
# 366 - 3 messages - navisai_ec8nh887wa
# 367 - 3 messages - maevewiesen_l3wti_pvpq
# 368 - 3 messages - katiewang_hjepwc6ipw
# 369 - 3 messages - heeminsummerkim__fjige191q
# 370 - 3 messages - emilylo_5immd8bzrw
# 371 - 3 messages - darsanswaroopbellie_pllzmhuyva
# 372 - 3 messages - dachathurber_xjyrnqijaw
# 373 - 3 messages - aditiagarwalryanleungrebeccayeand7others_5bm7iy0hoq
# 374 - 2 messages - urilurie_rgij0dcuha
# 375 - 2 messages - tailochow_gym_zfckwg
# 376 - 2 messages - julietchihaya_jv3yjgqwoa
# 377 - 2 messages - judydurkin_p7p1du_klw
# 378 - 2 messages - joycekang_ksefju4lwg
# 379 - 2 messages - ericawu_4akmic_wjq
# 380 - 2 messages - christinayeerachelphanandclarencechan_zrwwj7jkoq
# 381 - 1 messages - trevorjames_nyoraydzta
# 382 - 1 messages - samanthatham_pmcq5kpddq
# 383 - 1 messages - michaelyin_tvwym_hz1q
# 384 - 1 messages - kevinhuang_lh3a8yh-fw
# 385 - 1 messages - courtneyzang_aawd0aymzq
# 386 - 1 messages - averygehring_hlmm5bkppg
# 387 - 1 messages - anthonyzhu_8sblfg6hza
# 388 - 1 messages - andrewlu_b4n0nrofzq
# Found 12962 invalid messages...
# Found 388 chats with 0 messages or more

# %%
def plot_num_messages(chat_number):
    plotted_data = final_data_messages[chat_number]
    X = np.arange(len(plotted_data))
    pl.bar(X, list(plotted_data.values()), align='center', width=0.5, color = 'r', bottom = 0.3)
    pl.xticks(X, plotted_data.keys(), rotation = 90)
    pl.title('Number of Messages Sent')
    pl.tight_layout()
    pl.show()
    
    
def plot_histogram_time(chat_number):
    person_to_times = final_data_times[chat_number]
    pl.xlabel('Time')
    pl.ylabel('Number of Messages')
    pl.title('# of Messages Over Time')
    colors = ['b', 'r', 'c', 'm', 'y', 'k', 'w', 'g']
    for i , person in enumerate(person_to_times):
        plotted_data = []
        for time in person_to_times[person]:
            plotted_data.append(time)
        pl.hist(plotted_data, 100, alpha=0.3, label=person, facecolor=colors[i % len(colors)])
    pl.legend()
    pl.xticks(rotation=90)
    pl.tight_layout()
    pl.show()
    
def plot_histogram_words(chat_number):
    temp = {}
    for person in final_data_words[chat_number]:
        temp[person] = np.average(final_data_words[chat_number][person])
    plotted_data = temp
    X = np.arange(len(plotted_data))
    pl.bar(X, list(plotted_data.values()), align='center', width=0.5, color = 'r', bottom = 0.3)
    pl.xticks(X, plotted_data.keys(), rotation = 90)
    pl.title('Average Word Count')
    pl.tight_layout()
    pl.show()
    
def plot(chat_number):
    plot_num_messages(chat_number)
    plot_histogram_time(chat_number)
    plot_histogram_words(chat_number)

# %%
plot(190)

# %%
def find_phrase ():
    X = np.arange(len(tireds))
    pl.bar(X, list(tireds.values()), align='center', width=0.5, color = 'b')
    pl.xticks(X, tireds.keys(), rotation = 90)
    pl.title('Most Messages with \'im tired\'')
    pl.tight_layout()
    pl.show()

find_phrase()

# %%
print('People w/ most foul language: ' + str(nlargest(3, swearers, key = swearers.get)))
# Out:
# People w/ most foul language: [u'Yooni Park', u'Vivian Li', u'Jen Lo']

# %%
print('Most common exchanges: ' + str(nlargest(3, commonexchanges, key = commonexchanges.get)))
# Out:
# Most common exchanges: [u'LOL', u'...', u'XD']

# %%
def message_times(chat_number):
    timestamps = []
    messages = sorted_chats[chat_number][2]
    name = sorted_chats[chat_number][1]
    for message in messages:
        timestamp = message['timestamp_ms']
        time_data = datetime.fromtimestamp(timestamp/1000.0)
        hour = time_data.hour
        timestamps.append(hour)
    pl.xlabel('Time')
    pl.ylabel('Number of Messages')
    pl.title('Plot of Common Message Times')
    colors = ['b', 'r', 'c', 'm', 'y', 'k', 'w', 'g']
    pl.hist(timestamps, 100, alpha=0.3, label=name, facecolor=colors[i % len(colors)])
    pl.legend()
    pl.xticks(rotation=90)
    pl.tight_layout()
    pl.show()

# %%
message_times(3)
